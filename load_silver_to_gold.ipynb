# %%
import os
import pandas as pd

# %%
silver_path = os.path.join(os.curdir, "Data_Lake","Silver")
gold_path = os.path.join(os.curdir, "Data_Lake","Gold")

# %%
silver_file_name = "atletas_silver.csv"
gold_file_name = "atletas_gold.csv"

# %%
silver_file_path = os.path.join(silver_path,silver_file_name)
gold_file_path = os.path.join(gold_path,gold_file_name)

# %%
silver_atletas_df  = pd.read_csv(silver_file_path)

# %%
silver_atletas_df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight  NOC        Games  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0  CHN  1992 Summer
# 1   2                  A Lamusi   M  23.0   170.0    60.0  CHN  2012 Summer
# 2   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  NED  1988 Winter
# 3   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  NED  1988 Winter
# 4   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0  NED  1992 Winter
#
#    Year  Season         City          Sport  \
# 0  1992  Summer    Barcelona     Basketball
# 1  2012  Summer       London           Judo
# 2  1988  Winter      Calgary  Speed Skating
# 3  1988  Winter      Calgary  Speed Skating
# 4  1992  Winter  Albertville  Speed Skating
#
#                                 Event Medal            _BronzeTimestamp  \
# 0         Basketball Men's Basketball   NaN  2025-11-06 16:43:18.047773
# 1        Judo Men's Extra-Lightweight   NaN  2025-11-06 16:43:18.047773
# ...

# %%
#Solo me quiero quedar con los jjoo de verano, asi que procedo a eliminar las filas de los atletas de jjoo de invierno
silver_atletas_verano_df = silver_atletas_df

# %%
silver_atletas_verano_df = silver_atletas_verano_df[silver_atletas_verano_df['Season'] == "Summer"]

# %%
silver_atletas_verano_df['Season'].value_counts(dropna = False)
# Out:
# Season
# Summer    158147
# Name: count, dtype: int64

# %%
silver_atletas_verano_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 158147 entries, 0 to 199830
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   ID                158147 non-null  int64
#  1   Name              158147 non-null  object
#  2   Sex               158147 non-null  object
#  3   Age               157318 non-null  float64
#  4   Height            151117 non-null  float64
#  5   Weight            150854 non-null  float64
#  6   NOC               158147 non-null  object
#  7   Games             158147 non-null  object
#  8   Year              158147 non-null  int64
#  9   Season            158147 non-null  object
#  10  City              158147 non-null  object
#  11  Sport             158147 non-null  object
#  12  Event             158147 non-null  object
#  13  Medal             22634 non-null   object
#  14  _BronzeTimestamp  158147 non-null  object
#  15  Country           158147 non-null  object
# ...

# %%
#Creo carpeta
os.makedirs(gold_path, exist_ok=True)

# %%
silver_atletas_verano_df.to_csv(gold_file_path, index=False)
